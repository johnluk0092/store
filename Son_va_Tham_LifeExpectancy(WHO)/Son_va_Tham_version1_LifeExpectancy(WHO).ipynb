# %% [markdown]
# # <font color = "green">**Tìm hiểu và trực quan hóa dữ liệu cho Life Expectancy (WHO)**</font>

# %% [markdown]
# ## Nguồn dữ liệu:
#
# https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who

# %% [markdown]
# ## Nội dung vấn đề:
#
#     Mặc dù đã có nhiều nghiên cứu về các yếu tố ảnh hưởng đến tuổi thọ khi dựa trên các biến của nhân khẩu học, thu nhập và tỷ lệ tử vong.
#     Trước đây đã không tính đến ảnh hưởng của chỉ số tiêm chủng và phát triển con người.
#     Ngoài ra, một số nghiên cứu trước đây đã được thực hiện multiple linear regression dựa trên tập dữ liệu của một năm cho tất cả các quốc gia.
#
#     Do đó, điều này tạo động lực để giải quyết cả hai yếu tố đã nêu trước đây bằng cách xây dựng mô hình hồi quy dựa trên tác động của nhiểu yếu tố và hồi quy tuyến tính bội trong khi xem xét dữ liệu từ giai đoạn 2000 đến 2015 cho tất cả các quốc gia.
#     Việc chủng ngừa quan trọng như Viêm gan B, Bại liệt và Bạch hầu cũng sẽ được xem xét.
#
#     Tóm lại, nghiên cứu này sẽ tập trung vào các yếu tố miễn dịch, yếu tố tử vong, yếu tố kinh tế, yếu tố xã hội và các yếu tố liên quan đến sức khỏe khác.
#     Vì các quan sát trong tập dữ liệu này dựa trên các quốc gia khác nhau, nên tên một quốc gia sẽ quan trọng trong việc xác định yếu tố đang góp phần làm giảm giá trị tuổi thọ.
#     Điều này sẽ giúp gợi ý cho một quốc gia về lĩnh vực nào cần được coi trọng để nâng cao tuổi thọ của dân số một cách hiệu quả.

# %% [markdown]
# ## Nội Dung Dữ liệu:
#
#     Tập dữ liệu dựa trên kho dữ liệu của Global Health Observatory (GHO) thuộc Tổ chức Y tế Thế giới (WHO) theo dõi tình trạng sức khỏe cũng như nhiều yếu tố liên quan khác của tất cả các quốc gia.
#
#     Tập dữ liệu liên quan đến tuổi thọ, các yếu tố sức khỏe của 193 quốc gia đã được thu thập từ cùng một trang web kho dữ liệu của WHO và dữ liệu kinh tế  được thu thập từ trang web của United Nation.
#
#     Trong số tất cả các loại yếu tố liên quan đến sức khỏe, chỉ lựa chọn những yếu tố quan trọng mang tính đại diện.
#     Có thể thấy rằng trong 15 năm qua, lĩnh vực y tế đã có sự phát triển vượt bậc dẫn đến cải thiện tỷ lệ tử vong ở người, đặc biệt là ở các nước đang phát triển so với 30 năm qua.
#
#     Tập dữ liệu có dữ liệu từ năm 2000-2015 của 193 quốc gia
#
#     Khi kiểm tra trực quan ban đầu của dữ liệu cho thấy một số giá trị bị thiếu. Vì bộ dữ liệu được lấy từ WHO. Dữ liệu bị thiếu đã được xử lý trong phần mềm R bằng lệnh Missmap.
#
#     Kết quả chỉ ra rằng hầu hết các dữ liệu bị thiếu là về dân số, Viêm gan B và GDP.
#
#     Dữ liệu bị thiếu là từ các quốc gia ít được biết đến như Vanuatu, Tonga, Togo, Cabo Verde, ... Việc tìm kiếm tất cả dữ liệu cho các quốc gia này rất khó khăn và do đó đã loại trừ các quốc gia này khỏi tập dữ liệu mô hình cuối cùng.
#
#     Tệp được hợp nhất cuối cùng (tập dữ liệu cuối cùng) bao gồm 22 Cột và 2938 hàng, có nghĩa là 20 biến dự đoán.
#
#     Tất cả các biến dự đoán sau đó được chia thành nhiều loại lớn: Yếu tố liên quan đến tiêm chủng, Yếu tố tử vong, Yếu tố kinh tế và Yếu tố xã hội

# %% [markdown]
# ## Vấn đề đặt ra:
#
#     1. Các yếu tố dự đoán khác nhau đã được chọn ban đầu có thực sự ảnh hưởng đến Tuổi thọ không? Các biến dự đoán thực sự ảnh hưởng đến tuổi thọ là gì?
#     2. Một quốc gia có giá trị tuổi thọ thấp hơn (<65) có nên tăng chi tiêu cho chăm sóc sức khỏe để cải thiện tuổi thọ trung bình của mình không?
#     3. Kỳ vọng sống có mối tương quan tích cực hay tiêu cực với thói quen ăn uống, lối sống, tập thể dục, hút thuốc, uống rượu, v.v.
#     4. Tác động của việc đi học đối với tuổi thọ của con người là gì?
#     5. Kỳ vọng sống  (Life Expectancy) có mối quan hệ tích cực hay tiêu cực với việc uống rượu?
#     6. Các quốc gia đông dân cư có xu hướng có tuổi thọ thấp hơn?
#     7. Tác động của phạm vi Tiêm chủng đối với Sự mong đợi trong cuộc sống là gì?

# %% [markdown]
# # <font color = "blue">**Tài liệu tham khảo**</font>

# %% [markdown]
# https://ourworldindata.org/life-expectancy#twice-as-long-life-expectancy-around-the-world
#
# https://www.worldometers.info/demographics/life-expectancy/

# %% [markdown]
# # <font color = "blue">**Phần A. Chuẩn bị và làm sạch dữ liệu**</font>

# %% [markdown]
# # Connect Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# đường dẫn thư mục sẽ làm việc
WorkingPath = "/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)"
# %cd $WorkingPath

# %pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1H7i1CBcxI8Pn7T18FddrSgvSlG6LY8XN/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)
# '/content/drive/.shortcut-targets-by-id/1H7i1CBcxI8Pn7T18FddrSgvSlG6LY8XN/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)'

# %% [markdown]
# # Import Libraries

# %%
#pip install matplotlib==3.4.2
# !pip install matplotlib==3.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1) Read File

# %%
data_LifeExpectancy = pd.read_csv('Life Expectancy Data.csv')
data_LifeExpectancy.head(3)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.00           263.00
# 1  Afghanistan  2014  Developing             59.90           271.00
# 2  Afghanistan  2013  Developing             59.90           268.00
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01                   71.28        65.00      1154  ...
# 1             64     0.01                   73.52        62.00       492  ...
# 2             66     0.01                   73.22        64.00       430  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS    GDP    Population  \
# 0   6.00               8.16        65.00       0.10 584.26 33,736,494.00
# 1  58.00               8.18        62.00       0.10 612.70    327,582.00
# 2  62.00               8.13        64.00       0.10 631.74 31,731,688.00
#
#     thinness  1-19 years   thinness 5-9 years  \
# ...

# %% [markdown]
# **Mô tả dữ liệu:**
#
# * Country (Nominal) - tên của các nước trên thế giới, gồm 193 nước
# * Year (Ordinal) - năm dương lịch của các chỉ số (dao động từ 2000 đến 2015)
# * Status (Nominal) - một quốc gia được coi là 'Đang phát triển' hay 'Đã phát triển' theo các tiêu chuẩn của WHO
# * Life expectancy (Ratio) - tuổi thọ trung bình của người dân tính theo năm đối với một quốc gia và năm cụ thể
# * Adult Mortality (Ratio) - tỷ lệ tử vong của người trưởng thành trên 1000 dân số (tức là số người chết từ 15 đến 60 tuổi trên 1000 dân số), nếu tỉ lệ là 263 nghĩa là có 263 người chết trong số 1000 người có độ tuổi từ 15 đến 60. một cách khác để giải thích điều này là xác suất một cá nhân chết trong khoảng từ 15 đến 60 là 26,3%
# * infant deaths (Ratio) - số trẻ sơ sinh tử vong trên 1000 dân số
# * Alcohol (Ratio) - Tỷ lệ tiêu thụ rượu của một quốc gia được đo bằng lít/người
# * percentage expenditure(Ratio) - chi tiêu cho y tế tính theo tỷ lệ phần trăm của Tổng sản phẩm quốc nội (gdp)
# * Hepatitis B (Ratio) - số trẻ 1 tuổi được tiêm ngừa viêm gan B trên tất cả các trẻ 1 tuổi trong dân số
# * Measles (Ratio) - số ca mắc bệnh Sởi được báo cáo trên 1000 dân số
# * BMI (Interval/Ordinal) - Chỉ số khối cơ thể trung bình (BMI) của tổng dân số của một quốc gia
# * under-five deaths (Ratio) - số người dưới 5 tuổi tử vong trên 1000 dân số
# * Polio (Ratio) - số trẻ 1 tuổi được tiêm ngừa vắc xin bại liệt trên tổng số trẻ 1 tuổi trong dân số
# * Total expenditure (Ratio) - chi tiêu chính phủ cho y tế tính theo tỷ lệ phần trăm tổng chi tiêu chính phủ
# * Diphtheria (Ratio) - Tỷ lệ tiêm chủng uốn ván và ho gà (DTP3) của trẻ 1 tuổi
# *  HIV/AIDS (Ratio) - số trẻ dưới 5 tuổi chết do HIV / AIDS trên 1000 ca sinh.
# * GDP (Ratio) - Tổng sản phẩm quốc nội bình quân đầu người
# * Population (Ratio) - dân số của một quốc gia
# *  thinness  1-19 years (Ratio) - tỷ lệ gầy của những người từ 10-19 tuổi (Lưu ý: biến nên được đổi tên thành thinness_10-19_years để thể hiện chính xác hơn ý nghĩa và nội dung biến)
# *  thinness 5-9 years (Ratio) - tỷ lệ gầy của trẻ từ 5 đến 9 tuổi
# * Income composition of resources (Ratio) - Chỉ số Phát triển Con người xét về cơ cấu thu nhập của các nguồn lực (chỉ số từ 0 đến 1)
# * Schooling (Ratio) - số năm đi học trung bình của dân số

# %% [markdown]
# # 2) data.info

# %%
data_LifeExpectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
number_type = [f for f in data_LifeExpectancy.columns if data_LifeExpectancy.dtypes[f] != 'object']
print ("các cột đã là dạng số:", number_type)

object_type = [f for f in data_LifeExpectancy.columns if data_LifeExpectancy.dtypes[f] == 'object']
print ("các cột đang là dạng string:", object_type)
# Out:
# các cột đã là dạng số: ['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources', 'Schooling']
# các cột đang là dạng string: ['Country', 'Status']

# %% [markdown]
# # 3) kiểm tra null

# %%
# đếm giá trị null
count_nan_in_data = data_LifeExpectancy.isnull().sum()
print (count_nan_in_data)

# lấy index của vị trí null
#whereIsNaN = np.where(data['tên cột'].isnull() == True)
#print('vị trí tên cột có giá trị NaN: ', whereIsNaN)
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
percent_missing = data_LifeExpectancy.isnull().sum() * 100 / len(data_LifeExpectancy)
percent_missing = pd.DataFrame(percent_missing, columns=["NaN_percentage"])
percent_missing['NaN_percentage'] = percent_missing['NaN_percentage'].apply(lambda x: float("{:.2f}".format(x)))
percent_missing['NaN_percentage'] = percent_missing['NaN_percentage'].astype(str) + '%' 

pd.options.display.float_format = "{:,.2f}".format
percent_missing
# Out:
#                                 NaN_percentage
# Country                                   0.0%
# Year                                      0.0%
# Status                                    0.0%
# Life expectancy                          0.34%
# Adult Mortality                          0.34%
# infant deaths                             0.0%
# Alcohol                                   6.6%
# percentage expenditure                    0.0%
# Hepatitis B                             18.82%
# Measles                                   0.0%
#  BMI                                     1.16%
# under-five deaths                         0.0%
# Polio                                    0.65%
# Total expenditure                        7.69%
# Diphtheria                               0.65%
#  HIV/AIDS                                 0.0%
# GDP                                     15.25%
# Population                              22.19%
#  thinness  1-19 years                    1.16%
# ...

# %% [markdown]
# nhận xét:
#
#     dữ liệu có khá nhiều giá trị missing

# %% [markdown]
# # <font color = "red"> ** Tỉ lệ % dữ liệu missing ở mỗi feature so với tổng số mẫu là bao nhiêu???**</font>

# %% [markdown]
# # 4) data shape

# %%
# xem dữ liệu có bao nhiêu dòng, cột
data_LifeExpectancy.shape
# Out:
# (2938, 22)

# %% [markdown]
# # 5) có quan sát trùng nhau không

# %%
# kiểm tra xem có dòng nào bị trùng không 
print('dữ liệu có dòng trùng lặp hay không, true là có trùng, False là không trùng: kết quả là ', data_LifeExpectancy.duplicated().any())

# đếm số lượng dòng trùng lặp
count_dupli_in_data = data_LifeExpectancy.duplicated().sum()
print ('số lượng dòng trùng lặp: ', count_dupli_in_data)

# lấy index của vị trí trùng lặp
a = data_LifeExpectancy.duplicated(keep=False)
for i in range(len(a)):
  if a[i] == True:
    print('dòng trùng: ', i)
# Out:
# dữ liệu có dòng trùng lặp hay không, true là có trùng, False là không trùng: kết quả là  False
# số lượng dòng trùng lặp:  0

# %% [markdown]
# # 6) xử lý các giá trị missing

# %%
# đếm giá trị null
count_nan_in_data = data_LifeExpectancy.isnull().sum()
print (count_nan_in_data)

# lấy index của vị trí null
#whereIsNaN = np.where(data['tên cột'].isnull() == True)
#print('vị trí tên cột có giá trị NaN: ', whereIsNaN)
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax = sns.heatmap(data_LifeExpectancy.corr(), vmin=-1, vmax=1, annot=True);

# %% [markdown]
# # 6_1) xử lý các giá trị missing của biến Life expectancy

# %%
LifeExp0 = pd.read_html('https://vi.wikipedia.org/wiki/B%E1%BA%A3ng_x%E1%BA%BFp_h%E1%BA%A1ng_%C6%B0%E1%BB%9Bc_l%C6%B0%E1%BB%A3ng_tu%E1%BB%95i_th%E1%BB%8D_khi_sinh_theo_qu%E1%BB%91c_gia')
LifeExp1 = gdp[3][['Nước / Vùng lãnh thổ', 'WHO 2013']]

LifeExp = pd.DataFrame()
LifeExp['Country'] = LifeExp1['Nước / Vùng lãnh thổ']
LifeExp['TuoiTho'] = LifeExp1['WHO 2013']['Tổng']
LifeExp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-194-056c22d81cdb> in <module>()
#       1 LifeExp0 = pd.read_html('https://vi.wikipedia.org/wiki/B%E1%BA%A3ng_x%E1%BA%BFp_h%E1%BA%A1ng_%C6%B0%E1%BB%9Bc_l%C6%B0%E1%BB%A3ng_tu%E1%BB%95i_th%E1%BB%8D_khi_sinh_theo_qu%E1%BB%91c_gia')
# ----> 2 LifeExp1 = gdp[3][['Nước / Vùng lãnh thổ', 'WHO 2013']]
#       3
#       4 LifeExp = pd.DataFrame()
#       5 LifeExp['Country'] = LifeExp1['Nước / Vùng lãnh thổ']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ...

# %%
# đổi tên quốc gia trong LifeExp giống với data_LifeExpectancy
LifeExp.Country[LifeExp.Country == 'Quần đảo Cook (NZ)'] = 'Cook Islands'
LifeExp.Country[LifeExp.Country == 'Quần đảo Marshall'] = 'Marshall Islands'
LifeExp.Country[LifeExp.Country == 'Saint Kitts và Nevis'] = 'Saint Kitts and Nevis'

# %%
# 'Niue' không có tên trong LifeExp0
# 'Niue' được bao quanh bởi các nước ['Cook Islands', 'Tonga', 'Samoa', 'Tuvalu']
# nên thay trung bình tuổi thọ của 'Niue' bằng trung bình tuổi thọ ('Cook Islands' + 'Tonga' + 'Samoa' + 'Tuvalu')/4

tongTuoiTho = 0

for name_country in ['Cook Islands', 'Tonga', 'Samoa', 'Tuvalu']:
  tongTuoiTho += LifeExp.query('Country == "{}"'. format(name_country))['TuoiTho'].values[0]

trungBinh_tuoiTho_Niue = tongTuoiTho/4
trungBinh_tuoiTho_Niue

# %%
# thay thế giá trị missing
CountryLifeExp_missing_2013 = ['Cook Islands', 'Dominica', 'Marshall Islands', 'Monaco', 'Nauru', 'Palau', 'Saint Kitts and Nevis', 'San Marino', 'Tuvalu']

for name_country in CountryLifeExp_missing_2013:
  data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == name_country) & (data_LifeExpectancy['Year'] == 2013), 'Life expectancy '] = LifeExp.query('Country == "{}"'. format(name_country))['TuoiTho'].values[0]

# thay thế giá trị missing của 'Niue'
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Niue') & (data_LifeExpectancy['Year'] == 2013), 'Life expectancy '] = trungBinh_tuoiTho_Niue

# %%
# đếm giá trị null
count_nan_in_data = data_LifeExpectancy.isnull().sum()
print (count_nan_in_data)

# %% [markdown]
# # 6_2) xử lý các giá trị missing của biến Adult Mortality

# %% [markdown]
# 1) xem tỷ lệ tử vong của Monaco ở đây https://www.indexmundi.com/g/g.aspx?c=mn&v=26
#
# **tỷ lệ tử vong của Monaco năm 2013 là 8.75**

# %% [markdown]
# 2) xem tỷ lệ tử vong của Nauru ở đây https://www.indexmundi.com/g/g.aspx?v=26&c=nr&l=en
#
# **tỷ lệ tử vong của Nauru năm 2013 là 5.94**

# %% [markdown]
# 3) xem tỷ lệ tử vong của Marshall Islands ở đây https://www.indexmundi.com/g/g.aspx?v=26&c=rm&l=en
#
# **tỷ lệ tử vong của Marshall Islands năm 2013 là 4.27**

# %% [markdown]
# 4) xem tỷ lệ tử vong của Cook Islands ở đây https://www.indexmundi.com/g/g.aspx?v=26&c=cw&l=en
#
# **tỷ lệ tử vong của Cook Islands năm 2013 là 7.66**

# %% [markdown]
# 5) xem tỷ lệ tử vong của Dominica ở đây https://www.indexmundi.com/g/g.aspx?v=26&c=do&l=en
#
# **tỷ lệ tử vong của Dominica năm 2013 là 7.97**

# %% [markdown]
# 6) xem tỷ lệ tử vong của Palau ở đây https://www.indexmundi.com/g/g.aspx?v=26&c=ps&l=en
#
# **tỷ lệ tử vong của Palau năm 2013 là 7.86**

# %% [markdown]
# 7) xem tỷ lệ tử vong của Saint Kitts and Nevis ở đây https://www.indexmundi.com/g/g.aspx?v=26&c=sc&l=en
#
# **tỷ lệ tử vong của Saint Kitts and Nevis năm 2013 là 7.06**

# %% [markdown]
# 8) xem tỷ lệ tử vong của San Marino ở đây https://www.indexmundi.com/g/g.aspx?v=26&c=sm&l=en
#
# **tỷ lệ tử vong của San Marino năm 2013 là 8.17**

# %% [markdown]
# 9) xem tỷ lệ tử vong của Tuvalu ở đây https://www.indexmundi.com/g/g.aspx?v=26&c=tv&l=en
#
# **tỷ lệ tử vong của Tuvalu năm 2013 là 8.97**

# %%
mean_Country_AdultMortality = data_LifeExpectancy.groupby('Country')['Adult Mortality'].mean()
mean_Country_AdultMortality

# %%
#'Niue' được bao quanh bởi các nước ['Cook Islands', 'Tuvalu', 'Tonga', 'Samoa', 'Fiji']
# nên thay Adult Mortality của 'Niue' bằng Adult Mortality ('Cook Islands' + 'Tuvalu' + 'Tonga' + 'Samoa' + 'Fiji')/5

tyleTuVong_Niue = (7.66 + 8.97 + mean_Country_AdultMortality['Tonga'] + mean_Country_AdultMortality['Samoa'] + mean_Country_AdultMortality['Fiji'])/5
tyleTuVong_Niue

# %%
# thay thế các giá trị bị missing
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Monaco') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 8.75                             #1
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Nauru') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 5.94                              #2
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Marshall Islands') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 4.27                   #3
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Cook Islands') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 7.66                       #4
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Dominica') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 7.97                           #5
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Palau') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 7.86                              #6
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Saint Kitts and Nevis') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 7.06              #7
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'San Marino') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 8.17                         #8
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Tuvalu') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] = 8.97                             #9
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Niue') & (data_LifeExpectancy['Year'] == 2013), 'Adult Mortality'] =  tyleTuVong_Niue                   #10

# %%
# đếm giá trị null
count_nan_in_data = data_LifeExpectancy.isnull().sum()
print (count_nan_in_data)

# %% [markdown]
# # 6_3) xử lý các giá trị missing của biến Alcohol

# %%
sum_Country_Alcohol = data_LifeExpectancy.groupby('Country')['Alcohol'].sum()
mean_Country_Alcohol = sum_Country_Alcohol/14   # có 14 giá trị, cho 14 năm. năm 2015 là năm thứ 15

meanTotal_Country_Alcohol = data_LifeExpectancy['Alcohol'].sum()/(2938 - 194)     # có tổng 2938 quan sát, biến Alcohol có 194 quan sát bị missing

# %%
# những nước này có Alcohol thay đổi, không nhìn được xu hướng
# nên thay thế giá trị missing bằng trung bình Alcohol của đất nước đó
Country_missing_2015_byMean = ['Algeria', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Belarus', 'Belgium', 'Brazil', 'Bulgaria', 'Burkina Faso', "Côte d'Ivoire",
                                 'Canada', 'Chad', 'Chile', 'Colombia', 'Comoros', 'Congo', 'Croatia', 'Cyprus', "Democratic People's Republic of Korea", 'Dominican Republic', 'Ecuador', 'El Salvador',
                                 'Equatorial Guinea', 'Ethiopia', 'Finland', 'Gabon', 'Germany', 'Greece', 'Grenada', 'Guyana', 'Haiti', 'Honduras', 'Hungary', 'Israel', 'Kenya', 'Latvia', 'Micronesia (Federated States of)',
                                 'Morocco', 'Mozambique', 'Myanmar', 'Nepal', 'Madagascar', 'Netherlands', 'Nicaragua', 'Nigeria', 'Pakistan', 'Paraguay', 'Peru', 'Philippines', 'Republic of Korea', 'Romania', 'Senegal', 'Slovakia', 'Slovenia',
                               'Spain', 'Thailand', 'Tunisia', 'Turkey', 'Turkmenistan', 'United Arab Emirates', 'United Republic of Tanzania', 'Uruguay', 'Yemen', 'Zambia']

for name_country in Country_missing_2015_byMean:
  data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == name_country) & (data_LifeExpectancy['Year'] == 2015), 'Alcohol'] = mean_Country_Alcohol['{}'.format(name_country)]

#########################################################################################################################################################################################################################
# những nước này có Alcohol thay đổi, có xu hướng
# nên thay thế giá trị missing bằng Alcohol năm gần nhất của đất nước đó
Country_missing_2015_by2014 = ['Angola', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belize', 'Benin', 'Bhutan', 'Bolivia (Plurinational State of)', 'Bosnia and Herzegovina', 'Botswana',
                                 'Brunei Darussalam', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Central African Republic', 'China', 'Costa Rica', 'Cuba', 'Czechia', 'Democratic Republic of the Congo',
                                 'Denmark', 'Djibouti', 'Egypt', 'Eritrea', 'Estonia', 'Fiji', 'France', 'Gambia', 'Georgia', 'Ghana', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Iceland', 'India', 'Indonesia',
                                 'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic",
                                 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Lithuania', 'Luxembourg', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Mauritania', 'Mauritius', 'Mexico', 'Mongolia', 'Montenegro',
                                 'Montenegro', 'Namibia', 'Niger', 'Oman', 'Panama', 'Papua New Guinea', 'Poland', 'Portugal', 'Qatar', 'Republic of Moldova', 'Russian Federation', 'Rwanda', 'Saint Lucia',
                               'Saint Vincent and the Grenadines', 'Samoa', 'Sao Tome and Principe', 'Saudi Arabia', 'Serbia', 'Seychelles', 'Sierra Leone', 'Solomon Islands', 'Somalia', 'South Africa', 'Sri Lanka',
                               'Sudan', 'Suriname', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan', 'The former Yugoslav republic of Macedonia', 'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago',
                               'Uganda', 'Ukraine', 'United States of America', 'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Zimbabwe']

for name_country in Country_missing_2015_by2014:
  data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == name_country) & (data_LifeExpectancy['Year'] == 2015), 'Alcohol'] = (data_LifeExpectancy.query('Country == "{}" and Year == 2014'. format(name_country))).values[0][6]

#########################################################################################################################################################################################################################
# những nước này có Alcohol bị missing toàn bộ
# nên thay thế giá trị missing bằng Alcohol trung bình tổng thể
Country_missing_2015_byMeanTotal = ['South Sudan']

for name_country in Country_missing_2015_byMeanTotal:
  for i in range(2000, 2016):
    data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == name_country) & (data_LifeExpectancy['Year'] == i), 'Alcohol'] = meanTotal_Country_Alcohol

#########################################################################################################################################################################################################################
# các trường hợp đặc biệt
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Montenegro') & (data_LifeExpectancy['Year'] == 2005), 'Alcohol'] = (data_LifeExpectancy.query('Country == "Montenegro" and Year == 2004')).values[0][6]
data_LifeExpectancy.loc[(data_LifeExpectancy['Country'] == 'Palau') & (data_LifeExpectancy['Year'] == 2013), 'Alcohol'] = meanTotal_Country_Alcohol

# %%
# đếm giá trị null
count_nan_in_data = data_LifeExpectancy.isnull().sum()
print (count_nan_in_data)

# %% [markdown]
# # 6_4) xử lý các giá trị missing của biến Hepatitis B

# %% [markdown]
# # <font color = "red"> **Tại sao thay thế = 0????**</font>

# %% [markdown]
# các giá trị missing, là thời điểm nước đó chưa từng bắt đầu tổ chức tiêm vắc xin viêm gan B
#
# nên thế missing = 0

# %%
index_LifeExpectancy_HepatitisB_IsNaN = np.where(data_LifeExpectancy['Hepatitis B'].isnull() == True)

for i in index_LifeExpectancy_HepatitisB_IsNaN[0]:
  data_LifeExpectancy.loc[i, 'Hepatitis B'] = 0

# %%
# đếm giá trị null
count_nan_in_data = data_LifeExpectancy.isnull().sum()
print ('số lượng null của Hepatitis B là: ', count_nan_in_data['Hepatitis B'])
# Out:
# số lượng null của Hepatitis B là:  0

# %% [markdown]
# # 6_5) xử lý các giá trị missing của biến BMI

# %% [markdown]
# https://ourworldindata.org/obesity#body-mass-index-bmi

# %%
data_LifeExpectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2938 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
data_LifeExpectancy.query('Status == "Developing"').iloc[:, 10].mean()
# Out:
# 35.43532608695648

# %%
data_LifeExpectancy.iloc[:, 10].fillna(value=data_LifeExpectancy.query('Status == "Developing"').iloc[:, 10].mean(), inplace=True)

data_LifeExpectancy
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.00           263.00
# 1     Afghanistan  2014  Developing             59.90           271.00
# 2     Afghanistan  2013  Developing             59.90           268.00
# 3     Afghanistan  2012  Developing             59.50           272.00
# 4     Afghanistan  2011  Developing             59.20           275.00
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing             44.30           723.00
# 2934     Zimbabwe  2003  Developing             44.50           715.00
# 2935     Zimbabwe  2002  Developing             44.80            73.00
# 2936     Zimbabwe  2001  Developing             45.30           686.00
# 2937     Zimbabwe  2000  Developing             46.00           665.00
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
male_bmi= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/BMI/mean_bmi_males.csv')
female_bmi= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/BMI/mean_bmi_women.csv')
male_bmi
# Out:
#            Entity Code  Year  Mean BMI (male)
# 0     Afghanistan  AFG  1975            19.00
# 1     Afghanistan  AFG  1976            19.11
# 2     Afghanistan  AFG  1977            19.21
# 3     Afghanistan  AFG  1978            19.32
# 4     Afghanistan  AFG  1979            19.43
# ...           ...  ...   ...              ...
# 8815     Zimbabwe  ZWE  2012            22.18
# 8816     Zimbabwe  ZWE  2013            22.21
# 8817     Zimbabwe  ZWE  2014            22.24
# 8818     Zimbabwe  ZWE  2015            22.27
# 8819     Zimbabwe  ZWE  2016            22.30
#
# [8820 rows x 4 columns]

# %%
bmi = pd.concat([male_bmi, female_bmi], axis=1).reset_index()
bmi.rename(columns = {'Entity':'Country', 'Mean BMI (male)':'Mean_BMI_male', 'Mean BMI (female)':'Mean_BMI_female'}, inplace = True)
bmi = bmi.iloc[:, [1, 3, 4, 8]].query('2016 > Year >= 2000')
bmi
# Out:
#           Country  Year  Mean_BMI_male  Mean_BMI_female
# 25    Afghanistan  2000          21.37            22.17
# 26    Afghanistan  2001          21.46            22.30
# 27    Afghanistan  2002          21.54            22.44
# 28    Afghanistan  2003          21.63            22.57
# 29    Afghanistan  2004          21.71            22.70
# ...           ...   ...            ...              ...
# 8814     Zimbabwe  2011          22.15            25.25
# 8815     Zimbabwe  2012          22.18            25.28
# 8816     Zimbabwe  2013          22.21            25.32
# 8817     Zimbabwe  2014          22.24            25.36
# 8818     Zimbabwe  2015          22.27            25.39
#
# [3360 rows x 4 columns]

# %%
bmi['BMI'] = bmi.apply(lambda row: (row.Mean_BMI_male + row.Mean_BMI_female) / 2, axis=1)
bmi
# Out:
#           Country  Year  Mean_BMI_male  Mean_BMI_female   BMI
# 25    Afghanistan  2000          21.37            22.17 21.77
# 26    Afghanistan  2001          21.46            22.30 21.88
# 27    Afghanistan  2002          21.54            22.44 21.99
# 28    Afghanistan  2003          21.63            22.57 22.10
# 29    Afghanistan  2004          21.71            22.70 22.20
# ...           ...   ...            ...              ...   ...
# 8814     Zimbabwe  2011          22.15            25.25 23.70
# 8815     Zimbabwe  2012          22.18            25.28 23.73
# 8816     Zimbabwe  2013          22.21            25.32 23.76
# 8817     Zimbabwe  2014          22.24            25.36 23.80
# 8818     Zimbabwe  2015          22.27            25.39 23.83
#
# [3360 rows x 5 columns]

# %%
bmi.query('Country == "Micronesia (country)"')
# Out:
#                    Country  Year  Mean_BMI_male  Mean_BMI_female   BMI
# 5107  Micronesia (country)  2000          27.66            30.28 28.97
# 5108  Micronesia (country)  2001          27.68            30.36 29.02
# 5109  Micronesia (country)  2002          27.70            30.44 29.07
# 5110  Micronesia (country)  2003          27.73            30.52 29.12
# 5111  Micronesia (country)  2004          27.75            30.60 29.18
# 5112  Micronesia (country)  2005          27.78            30.68 29.23
# 5113  Micronesia (country)  2006          27.82            30.76 29.29
# 5114  Micronesia (country)  2007          27.86            30.83 29.35
# 5115  Micronesia (country)  2008          27.91            30.91 29.41
# 5116  Micronesia (country)  2009          27.95            30.99 29.47
# 5117  Micronesia (country)  2010          28.00            31.06 29.53
# 5118  Micronesia (country)  2011          28.06            31.14 29.60
# ...

# %%
bmi.Country[bmi.Country == 'Bolivia'] = 'Bolivia (Plurinational State of)'
bmi.Country[bmi.Country == "Brunei"] = "Brunei Darussalam"
bmi.Country[bmi.Country == "Cote d'Ivoire"] = "Côte d'Ivoire"
bmi.Country[bmi.Country == "Cape Verde"] = "Cabo Verde"
bmi.Country[bmi.Country == "North Korea"] = "Democratic People's Republic of Korea"
bmi.Country[bmi.Country == "Democratic Republic of Congo"] = "Democratic Republic of the Congo"
bmi.Country[bmi.Country == "Iran"] = "Iran (Islamic Republic of)"
bmi.Country[bmi.Country == "Laos"] = "Lao People's Democratic Republic"
bmi.Country[bmi.Country == "Micronesia (country)"] = "Micronesia (Federated States of)"
#bmi.Country[bmi.Country == 'Republic of North Macedonia'] = 'The former Yugoslav republic of Macedonia'
#bmi.Country[bmi.Country == 'United Republic of Tanzania: Mainland'] = 'United Republic of Tanzania'
#bmi.Country[bmi.Country == 'United States'] = 'United States of America'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
for i in range(len(data_LifeExpectancy)):
  Country = data_LifeExpectancy.loc[i, 'Country']
  Year = data_LifeExpectancy.loc[i, 'Year']
  print("Country là: {}        Year là: {}".format(Country, Year))
  print((bmi.query('Country == "{}" and Year == {}'. format(Country, Year))).values[0][3])
  #data_LifeExpectancy.loc[i, 'BMI_new'] = bmi.loc[bmi['Year'].isin([Year]) & bmi['Country'].isin([Country]), ['BMI']].values[0]
# Out:
# Country là: Afghanistan        Year là: 2015
# 24.10689909
# Country là: Afghanistan        Year là: 2014
# 23.97913537
# Country là: Afghanistan        Year là: 2013
# 23.85132667
# Country là: Afghanistan        Year là: 2012
# 23.72296541
# Country là: Afghanistan        Year là: 2011
# 23.59478507
# Country là: Afghanistan        Year là: 2010
# 23.4669499
# Country là: Afghanistan        Year là: 2009
# 23.33914778
# Country là: Afghanistan        Year là: 2008
# 23.21112543
# Country là: Afghanistan        Year là: 2007
# 23.08330994
# Country là: Afghanistan        Year là: 2006
# 22.9553998
# Country là: Afghanistan        Year là: 2005
# 22.82747585
# Country là: Afghanistan        Year là: 2004
# 22.69821087
# Country là: Afghanistan        Year là: 2003
# 22.56762969
# Country là: Afghanistan        Year là: 2002
# 22.43556899
# Country là: Afghanistan        Year là: 2001
# 22.30232938
# Country là: Afghanistan        Year là: 2000
# 22.16827048
# ...

# %% [markdown]
# # 6_6) xử lý các giá trị missing của biến Polio

# %% [markdown]
# anh Sơn giải thích, chứ em không đồng ý quan điểm này
# nhưng em đồng ý thay số 0

# %% [markdown]
# Timor-Leste giành được độc lập vào năm 2002
#
# https://history.state.gov/countries/timor-leste#:~:text=The%20United%20States%20recognized%20Timor,sovereignty%20from%201976%20to%201999.
#
# Montenegro giành được độc lập năm 2006
#
# https://en.wikipedia.org/wiki/Montenegro
#
# South Sudan giành được độc lập năm 2011
#
# https://en.wikipedia.org/wiki/South_Sudan
#
# do đó 3 nước trên số liệu trước đó chưa có do chưa tồn tại

# %%
index_LifeExpectancy_Polio_IsNaN = np.where(data_LifeExpectancy['Polio'].isnull() == True)

for i in index_LifeExpectancy_Polio_IsNaN[0]:
  data_LifeExpectancy.loc[i, 'Polio'] = 0

# %%
# đếm giá trị null
count_nan_in_data = data_LifeExpectancy.isnull().sum()
print ('số lượng null của Polio là: ', count_nan_in_data['Polio'])
# Out:
# số lượng null của Polio là:  0

# %% [markdown]
# # 6_7) xử lý các giá trị missing của Total expenditure

# %% [markdown]
# # 6_8) xử lý các giá trị missing của biến Diphtheria

# %% [markdown]
# # 6_9) xử lý các giá trị missing của biến GDP

# %% [markdown]
# https://data.un.org/Data.aspx?q=gdp&d=SNAAMA&f=grID%3a101%3bcurrID%3aUSD%3bpcFlag%3a1

# %%
GDP_1= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/GDP/UNdata_GDP_Afganistan_Czechia.csv')
GDP_2= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/GDP/UNdata_GDP_North_Kor_Kyrgyzstan.csv')
GDP_3= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/GDP/UNdata_GDP_Tajikistan_Zimbabwe.csv')
GDP_4= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/GDP/UNdata_Laos_Syria.csv')

GDP_ = pd.concat([GDP_1, GDP_2, GDP_3, GDP_4])
GDP_.rename(columns = {'Country or Area':'Country'}, inplace = True)

GDP_['Value'] = GDP_['Value'].astype(float)
GDP_['Value'] = GDP_['Value'].apply(lambda x: float("{:.2f}".format(x)))

GDP_
# Out:
#           Country  Year                          Item    Value
# 0     Afghanistan  2015  Gross Domestic Product (GDP)   543.77
# 1     Afghanistan  2014  Gross Domestic Product (GDP)   585.86
# 2     Afghanistan  2013  Gross Domestic Product (GDP)   608.06
# 3     Afghanistan  2012  Gross Domestic Product (GDP)   614.11
# 4     Afghanistan  2011  Gross Domestic Product (GDP)   576.10
# ...           ...   ...                           ...      ...
# 1319    Swaziland  2004  Gross Domestic Product (GDP) 2,797.02
# 1320    Swaziland  2003  Gross Domestic Product (GDP) 2,235.68
# 1321    Swaziland  2002  Gross Domestic Product (GDP) 1,473.72
# 1322    Swaziland  2001  Gross Domestic Product (GDP) 1,599.21
# 1323    Swaziland  2000  Gross Domestic Product (GDP) 1,818.67
#
# [3399 rows x 4 columns]

# %%
GDP_.Country[GDP_.Country == 'China (mainland)'] = 'China'
GDP_.Country[GDP_.Country == 'Iran, Islamic Republic of'] = 'Iran (Islamic Republic of)'
GDP_.Country[GDP_.Country == 'Republic of North Macedonia'] = 'The former Yugoslav republic of Macedonia'
GDP_.Country[GDP_.Country == 'United Republic of Tanzania: Mainland'] = 'United Republic of Tanzania'
GDP_.Country[GDP_.Country == 'United States'] = 'United States of America'

# %%
for i in range(len(data_LifeExpectancy)):
  Country = data_LifeExpectancy.loc[i, 'Country']
  Year = data_LifeExpectancy.loc[i, 'Year']
  data_LifeExpectancy.loc[i, 'GDP_new'] = GDP_.loc[GDP_['Year'].isin([Year]) & GDP_['Country'].isin([Country]), ['Value']].values[0]

# %%
data_LifeExpectancy
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.00           263.00
# 1     Afghanistan  2014  Developing             59.90           271.00
# 2     Afghanistan  2013  Developing             59.90           268.00
# 3     Afghanistan  2012  Developing             59.50           272.00
# 4     Afghanistan  2011  Developing             59.20           275.00
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing             44.30           723.00
# 2934     Zimbabwe  2003  Developing             44.50           715.00
# 2935     Zimbabwe  2002  Developing             44.80            73.00
# 2936     Zimbabwe  2001  Developing             45.30           686.00
# 2937     Zimbabwe  2000  Developing             46.00           665.00
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# đếm giá trị null
count_nan_in_data = data_LifeExpectancy.isnull().sum()
print ('số lượng null của GDP_new là: ', count_nan_in_data['GDP_new'])
# Out:
# số lượng null của GDP_new là:  0

# %% [markdown]
# # 6_10) xử lý các giá trị missing của biến Population

# %% [markdown]
# thay thế những giá trị missing bằng World Bank Data và dữ liệu của Liên Hợp Quốc
#
# nguồn: https://data.worldbank.org/ và  https://data.un.org/Data.aspx?q=population&d=PopDiv&f=variableID%3a12

# %% [markdown]
# * Note: dân số bình quân có đơn vị ngàn người

# %% [markdown]
# https://en.wikipedia.org/wiki/Eswatini

# %%
popu_1= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/population/UNdata_Pop_Afghanistan_Czechia.csv')
popu_2= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/population/UNdata_Pop_Haiti_Rwanda.csv')
popu_3= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/population/UNdata_Pop_North_Kor_Guyana.csv')
popu_4= pd.read_csv('/content/drive/MyDrive/TaiNguyenChung_Son_Tham/Son_va_Tham_LifeExpectancy(WHO)/population/UNdata_Pop_St_Helena_Zimbabwe.csv')

popu_ = pd.concat([popu_1, popu_2, popu_3, popu_4])


popu_.rename(columns = {'Country or Area':'Country', 'Year(s)':'Year'}, inplace = True)
popu_ = popu_.loc[popu_['Variant'] == "Medium"]

popu_['Value'] = popu_['Value'].astype(float)
popu_['Value'] = popu_['Value'].apply(lambda x: float("{:.2f}".format(x)))


popu_
# Out:
#           Country  Year Variant     Value
# 0     Afghanistan  2015  Medium 34,413.60
# 9     Afghanistan  2014  Medium 33,370.79
# 18    Afghanistan  2013  Medium 32,269.59
# 27    Afghanistan  2012  Medium 31,161.38
# 36    Afghanistan  2011  Medium 30,117.41
# ...           ...   ...     ...       ...
# 8451     Zimbabwe  2004  Medium 12,019.91
# 8460     Zimbabwe  2003  Medium 11,982.22
# 8469     Zimbabwe  2002  Medium 11,954.29
# 8478     Zimbabwe  2001  Medium 11,923.91
# 8487     Zimbabwe  2000  Medium 11,881.48
#
# [3808 rows x 4 columns]

# %%
popu_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3808 entries, 0 to 8487
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  3808 non-null   object
#  1   Year(s)  3808 non-null   int64
#  2   Variant  3808 non-null   object
#  3   Value    3808 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 148.8+ KB

# %%
popu_.Country[popu_.Country == "Dem. People's Republic of Korea"] = "Democratic People's Republic of Korea"
popu_.Country[popu_.Country == 'Micronesia'] = 'Micronesia (Federated States of)'
popu_.Country[popu_.Country == 'Eswatini'] = 'Swaziland'
popu_.Country[popu_.Country == 'North Macedonia'] = 'The former Yugoslav republic of Macedonia'
popu_.Country[popu_.Country == 'United Kingdom'] = 'United Kingdom of Great Britain and Northern Ireland'
#popu_.Country[popu_.Country == 'United States'] = 'United States of America'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
for i in range(len(data_LifeExpectancy)):
  Country = data_LifeExpectancy.loc[i, 'Country']
  Year = data_LifeExpectancy.loc[i, 'Year']
  #print("Country là: {}        Year là: {}".format(Country, Year))
  #print((popu_.query('Country == "{}" and Year == {}'. format(Country, Year))).values[0][3])
  data_LifeExpectancy.loc[i, 'Population_new'] = popu_.loc[popu_['Year'].isin([Year]) & popu_['Country'].isin([Country]), ['Value']].values[0]

# %%
data_LifeExpectancy
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.00           263.00
# 1     Afghanistan  2014  Developing             59.90           271.00
# 2     Afghanistan  2013  Developing             59.90           268.00
# 3     Afghanistan  2012  Developing             59.50           272.00
# 4     Afghanistan  2011  Developing             59.20           275.00
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing             44.30           723.00
# 2934     Zimbabwe  2003  Developing             44.50           715.00
# 2935     Zimbabwe  2002  Developing             44.80            73.00
# 2936     Zimbabwe  2001  Developing             45.30           686.00
# 2937     Zimbabwe  2000  Developing             46.00           665.00
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# # 6_11) xử lý các giá trị missing của biến  'thinness  1-19 years'

# %% [markdown]
# # 6_12) xử lý các giá trị missing của biến 'thinness 5-9 years'

# %% [markdown]
# # 6_13) xử lý các giá trị missing của biến 'Income composition of resources'

# %% [markdown]
# # 6_14) xử lý các giá trị missing của biến Schooling

# %%
data_LifeExpectancy.Country.unique().tolist()

# %%
data_LifeExpectancy.query('Country == "Afghanistan"')

# %%
data_LifeExpectancy.query('Country == "China"')

# %%
data_LifeExpectancy.query('Country == "United States of America"')
